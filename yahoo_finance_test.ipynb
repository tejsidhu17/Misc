# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Valid Time Periods: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max

data_dow = yf.download("DOW", period="5y")
data_spy = yf.download("SPY", period="5y")
data_vti = yf.download("VTI", period="5y")

data_dow['Percent Change'] = data_dow['Adj Close'].pct_change() * 100
data_spy['Percent Change'] = data_spy['Adj Close'].pct_change() * 100
data_vti['Percent Change'] = data_vti['Adj Close'].pct_change() * 100

print(data_spy)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-08-14  288.070007  288.739990  283.760010  283.899994  262.398743
# 2019-08-15  284.880005  285.640015  282.390015  284.649994  263.091949
# 2019-08-16  286.480011  289.329987  284.709991  288.850006  266.973816
# 2019-08-19  292.190002  293.079987  291.440002  292.329987  270.190338
# 2019-08-20  291.769989  292.359985  289.950012  290.089996  268.119934
# 2019-08-21  292.480011  292.859985  291.720001  292.450012  270.301270
# 2019-08-22  293.230011  293.929993  290.399994  292.359985  270.218048
# 2019-08-23  290.920013  292.760010  283.470001  284.850006  263.276917
# 2019-08-26  287.269989  288.000000  285.579987  288.000000  266.188263
# ...

# %%
msft = yf.Ticker("MSFT")
print(msft.info)

print(msft.income_stmt)
print(msft.quarterly_income_stmt)
# - balance sheet
print(msft.balance_sheet)
print(msft.quarterly_balance_sheet)
# - cash flow statement
print(msft.cashflow)
print(msft.quarterly_cashflow)
# Out:
# {'address1': 'One Microsoft Way', 'city': 'Redmond', 'state': 'WA', 'zip': '98052-6399', 'country': 'United States', 'phone': '425 882 8080', 'website': 'https://www.microsoft.com', 'industry': 'Software - Infrastructure', 'industryKey': 'software-infrastructure', 'industryDisp': 'Software - Infrastructure', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and p
# ...

# %%
intc = yf.Ticker("INTC")
print(intc.upgrades_downgrades)
# Out:
#                                            Firm              ToGrade  \
# GradeDate
# 2024-08-08 09:50:22                      Mizuho              Neutral
# 2024-08-02 22:41:24                  Rosenblatt                 Sell
# 2024-08-02 17:59:02   Northland Capital Markets           Outperform
# 2024-08-02 17:42:24                         UBS              Neutral
# 2024-08-02 17:18:02                    Roth MKM              Neutral
# 2024-08-02 14:58:52                    Barclays         Equal-Weight
# 2024-08-02 14:51:54           Cantor Fitzgerald              Neutral
# 2024-08-02 14:22:39                     Wedbush              Neutral
# 2024-08-02 13:06:28           Truist Securities                 Hold
# 2024-08-02 12:37:14                   JP Morgan          Underweight
# 2024-08-02 12:22:26                 Susquehanna              Neutral
# 2024-08-02 12:10:02              Morgan Stanley         Equal-Weight
# ...
